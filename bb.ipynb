# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('weatherAUS.csv')

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 145455    False
# 145456    False
# 145457    False
# 145458    False
# 145459    False
# Length: 145460, dtype: bool

# %%
df.duplicated().any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df.fillna(method='ffill',inplace=True)

# %%
df.isnull().any()
# Out:
# Date             False
# Location         False
# MinTemp          False
# MaxTemp          False
# Rainfall         False
# Evaporation       True
# Sunshine          True
# WindGustDir      False
# WindGustSpeed    False
# WindDir9am       False
# WindDir3pm       False
# WindSpeed9am     False
# WindSpeed3pm     False
# Humidity9am      False
# Humidity3pm      False
# Pressure9am      False
# Pressure3pm      False
# Cloud9am         False
# Cloud3pm          True
# Temp9am          False
# Temp3pm          False
# RainToday        False
# RainTomorrow     False
# dtype: bool

# %%
df.duplicated().any()
# Out:
# False

# %%
df.dropna(inplace=True)

# %%
df.isnull().any()
# Out:
# Date             False
# Location         False
# MinTemp          False
# MaxTemp          False
# Rainfall         False
# Evaporation      False
# Sunshine         False
# WindGustDir      False
# WindGustSpeed    False
# WindDir9am       False
# WindDir3pm       False
# WindSpeed9am     False
# WindSpeed3pm     False
# Humidity9am      False
# Humidity3pm      False
# Pressure9am      False
# Pressure3pm      False
# Cloud9am         False
# Cloud3pm         False
# Temp9am          False
# Temp3pm          False
# RainToday        False
# RainTomorrow     False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 6049    2009-01-01    Cobar     17.9     35.2       0.0         12.0
# 6050    2009-01-02    Cobar     18.4     28.9       0.0         14.8
# 6051    2009-01-03    Cobar     15.5     34.1       0.0         12.6
# 6052    2009-01-04    Cobar     19.4     37.6       0.0         10.8
# 6053    2009-01-05    Cobar     21.9     38.4       0.0         11.4
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0         10.0
# 145456  2017-06-22    Uluru      3.6     25.3       0.0         10.0
# 145457  2017-06-23    Uluru      5.4     26.9       0.0         10.0
# 145458  2017-06-24    Uluru      7.8     27.0       0.0         10.0
# 145459  2017-06-25    Uluru     14.9     27.0       0.0         10.0
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
len(df)
# Out:
# 139411

# %%
df.shape
# Out:
# (139411, 23)

# %%
df.tail()
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 145455  2017-06-21    Uluru      2.8     23.4       0.0         10.0
# 145456  2017-06-22    Uluru      3.6     25.3       0.0         10.0
# 145457  2017-06-23    Uluru      5.4     26.9       0.0         10.0
# 145458  2017-06-24    Uluru      7.8     27.0       0.0         10.0
# 145459  2017-06-25    Uluru     14.9     27.0       0.0         10.0
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 145455      10.7           E           31.0         SE  ...        51.0
# 145456      10.7         NNW           22.0         SE  ...        56.0
# 145457      10.7           N           37.0         SE  ...        53.0
# 145458      10.7          SE           28.0        SSE  ...        51.0
# 145459      10.7          SE           28.0        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall    Evaporation  \
# count  139411.000000  139411.000000  139411.000000  139411.000000
# mean       12.293479      23.214499       2.396132       6.392197
# std         6.402860       7.116853       8.555207       7.686005
# min        -8.500000      -4.800000       0.000000       0.000000
# 25%         7.700000      18.000000       0.000000       1.800000
# 50%        12.100000      22.700000       0.000000       4.200000
# 75%        17.000000      28.200000       0.800000       8.400000
# max        33.900000      48.100000     371.000000     145.000000
#
#             Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  139411.000000  139411.000000  139411.000000  139411.000000
# mean        7.053908      39.723085      14.305830      19.052535
# std         3.554725      13.587183       8.917924       9.075998
# min         0.000000       6.000000       0.000000       0.000000
# ...

# %%
total=df[['MinTemp', 'MaxTemp', 'Rainfall','Evaporation','Sunshine']]

# %%
total
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine
# 6049       17.9     35.2       0.0         12.0      12.3
# 6050       18.4     28.9       0.0         14.8      13.0
# 6051       15.5     34.1       0.0         12.6      13.3
# 6052       19.4     37.6       0.0         10.8      10.6
# 6053       21.9     38.4       0.0         11.4      12.2
# ...         ...      ...       ...          ...       ...
# 145455      2.8     23.4       0.0         10.0      10.7
# 145456      3.6     25.3       0.0         10.0      10.7
# 145457      5.4     26.9       0.0         10.0      10.7
# 145458      7.8     27.0       0.0         10.0      10.7
# 145459     14.9     27.0       0.0         10.0      10.7
#
# [139411 rows x 5 columns]

# %%
total_val = df["MaxTemp"].value_counts()
total_val.sort_values().plot(kind='bar', stacked=True)

plt.ylabel('MaxTemp')
plt.xlabel('Sunshine')
# Out:
# Text(0.5, 0, 'Sunshine')

# %%
total_volume = pd.DataFrame(df['MaxTemp'].value_counts())
total_volume.columns=['Sunshine']
total_volume.plot(kind='pie',y= 'Sunshine')
# Out:
# <AxesSubplot:ylabel='Sunshine'>

# %%
df['Sunshine'].hist();

# %%
df['MinTemp'].hist();

# %%
df['MaxTemp'].hist();

# %%
df['Evaporation'].hist();

# %%
df['Humidity3pm'].hist();

# %%
df.plot(x="Sunshine",y="Humidity3pm",kind="scatter")
# Out:
# <AxesSubplot:xlabel='Sunshine', ylabel='Humidity3pm'>

# %%
df.plot(x="MinTemp",y="Humidity9am",kind="scatter")
# Out:
# <AxesSubplot:xlabel='MinTemp', ylabel='Humidity9am'>

# %%
df.plot(x="MaxTemp",y="Cloud3pm",kind="scatter")
# Out:
# <AxesSubplot:xlabel='MaxTemp', ylabel='Cloud3pm'>

# %%
df.plot(x="Pressure9am",y="Pressure3pm",kind="scatter")
# Out:
# <AxesSubplot:xlabel='Pressure9am', ylabel='Pressure3pm'>
